# %% [markdown]
# # Week 1: Exercise 1 - Hello Agent
#
# **Goal:** Build the simplest possible agent.

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv("../.env")

client = OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai",
    api_key=os.environ.get("GEMINI_API_KEY"),
)
print("API client ready")
# Out:
# API client ready

# %% [markdown]
# ## Step 2: Implement hello_agent
#
# **TODO:** Call the LLM and return the answer.
# Use model `os.environ.get("GEMINI_MODEL")`.

# %%
def hello_agent(user_input: str) -> str:
    """
    TODO: Send a question to the LLM and return the answer.
    """
    # Hint: client.chat.completions.create(
    #           model=os.environ.get("GEMINI_MODEL"),
    #           messages=[{"role": "user", "content": user_input}])
    #       then return responds.choices[0].message.content
    responds = client.chat.completions.create(
        model = os.environ.get("GEMINI_MODEL"),
        messages = {
            "role" : "user",
            "content": user_input
        }
    )
    return responds.choices[0].message.content

# %% [markdown]
# ## Step 3: Test It

# %%
response = hello_agent("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# ## Key Takeaways
# - An agent starts with a simple API call
# - The response text is at `response.choices[0].message.content`
